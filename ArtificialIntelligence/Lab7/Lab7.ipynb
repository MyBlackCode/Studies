# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation

file = 'https://marcingabryel.pl/ai/iris.csv'
dataframe = pd.read_csv(file)

dataframe['y'] = dataframe['variety']
dataframe['y'] = dataframe['y'].replace('Setosa', 1.0)
dataframe['y'] = dataframe['y'].replace('Versicolor', 0.0)
dataframe['y'] = dataframe['y'].replace('Virginica', 0.0)

x = dataframe[ ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
y = dataframe['y']


x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2)

x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

M = 4
N = 4

model = Sequential()
model.add( Dense(M, activation='relu', input_dim=4) )
model.add(Dense(N, activation = 'relu'))
model.add( Dense(1, activation='sigmoid') )
model.compile(optimizer="adam", loss='binary_crossentropy' )

history = model.fit(x_train, y_train, epochs=30
                    , batch_size=1, verbose=1)

plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

y_result_train = model.predict(x_train)
y_result_train = np.round(y_result_train)
bledy = 0
for i in range(len(y_train)):
 if y_result_train[i] != y_train[i]:
   bledy += 1
print("Liczba bledow ciagu treningowego: ", bledy)

y_result_test = model.predict(x_test)
y_result_test = np.round(y_result_test)

bledy = 0

for i in range(len(y_test)):
  if y_result_test[i] != y_test[i]:
    bledy += 1

print("Liczba bledow ciagu testowego: ", bledy)
# Out:
# Epoch 1/30
# 120/120 [==============================] - 1s 1ms/step - loss: 0.4917
# Epoch 2/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4486
# Epoch 3/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4054
# Epoch 4/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.3597
# Epoch 5/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.3152
# Epoch 6/30
# 120/120 [==============================] - 0s 1ms/step - loss: 0.2820
# Epoch 7/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2583
# Epoch 8/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2376
# Epoch 9/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2220
# Epoch 10/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.2089
# Epoch 11/30
# 120/120 [==============================] - 0s 2ms/step - loss: 0.1978
# Epoch 12/30
# ...

# %%
dataframe['y2'] = dataframe['variety']
dataframe['y2'] = dataframe['y2'].replace('Setosa', 0.0)
dataframe['y2'] = dataframe['y2'].replace('Versicolor', 1.0)
dataframe['y2'] = dataframe['y2'].replace('Virginica', 0.0)

x2= dataframe[ ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
y2 = dataframe['y2']


x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, stratify=y2, test_size=0.2)

x2_train = x2_train.to_numpy()
x2_test = x2_test.to_numpy()
y2_train = y2_train.to_numpy()
y2_test = y2_test.to_numpy()


model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(5, activation='relu'))


model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy')

history = model.fit(x2_train, y2_train, epochs=200
                    , batch_size=1, verbose=1)

plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

y2_result_train = model.predict(x2_train)
y_2result_train = np.round(y2_result_train)
bledy = 0
for i in range(len(y2_train)):
 if y2_result_train[i] != y2_train[i]:
   bledy += 1
print("Liczba bledow ciagu treningowego: ", bledy)

y2_result_test = model.predict(x2_test)
y2_result_test = np.round(y2_result_test)

bledy = 0

for i in range(len(y2_test)):
  if y2_result_test[i] != y2_test[i]:
    bledy += 1

print("Liczba bledow ciagu testowego: ", bledy)

# %%
dataframe['y3'] = dataframe['variety']
dataframe['y3'] = dataframe['y3'].replace('Setosa', 0.0)
dataframe['y3'] = dataframe['y3'].replace('Versicolor', 0.0)
dataframe['y3'] = dataframe['y3'].replace('Virginica', 1.0)

x3 = dataframe[ ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
y3 = dataframe['y3']


x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, stratify=y3, test_size=0.2)

x3_train = x3_train.to_numpy()
x3_test = x3_test.to_numpy()
y3_train = y3_train.to_numpy()
y3_test = y3_test.to_numpy()


model = Sequential()
model.add( Dense(4, activation='relu', input_dim=4) )
model.add(Dense(4, activation='relu'))
model.add(Dense(4, activation='relu'))


model.add( Dense(1, activation='sigmoid') )
model.compile(optimizer="adam", loss='binary_crossentropy' )

history = model.fit(x3_train, y3_train, epochs=60
                    , batch_size=1, verbose=1)

plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

y3_result_train = model.predict(x3_train)
y3_result_train = np.round(y3_result_train)
bledy = 0
for i in range(len(y3_train)):
 if y3_result_train[i] != y3_train[i]:
   bledy += 1
print("Liczba bledow ciagu treningowego: ", bledy)

y3_result_test = model.predict(x3_test)
y3_result_test = np.round(y3_result_test)

bledy = 0

for i in range(len(y3_test)):
  if y3_result_test[i] != y3_test[i]:
    bledy += 1

print("Liczba bledow ciagu testowego: ", bledy)
# Out:
# Epoch 1/60
# 120/120 [==============================] - 1s 2ms/step - loss: 0.8742
# Epoch 2/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6752
# Epoch 3/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6286
# Epoch 4/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5770
# Epoch 5/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5313
# Epoch 6/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4868
# Epoch 7/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4643
# Epoch 8/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.4185
# Epoch 9/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3955
# Epoch 10/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3774
# Epoch 11/60
# 120/120 [==============================] - 0s 2ms/step - loss: 0.3496
# Epoch 12/60
# ...

# %%
x = dataframe[ ['sepal.length', 'sepal.width', 'petal.length', 'petal.width'] ]
y = dataframe[ ['y', 'y2', 'y3'] ]

x_train, x_test, y_train, y_test = train_test_split(x, y, stratify = y, test_size = 0.2)

x_train = x_train.to_numpy()
x_test = x_test.to_numpy()
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()


model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
#model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy')

history = model.fit(x_train, y_train,  epochs=220 ,batch_size=1, verbose=0)

plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

y_result_train = model.predict(x_train)
y_result_train = np.round(y_result_train)

bledySetosa = 0
bledyVersicolor = 0
bledyVirginica = 0

print(y_result_train.size)

for i in range(120):
  if y_result_train[i][0] != y_train[i][0]:
    bledySetosa += 1

for i in range(120):
  if y_result_train[i][1] != y_train[i][1]:
    bledyVersicolor += 1

for i in range(120):
  if y_result_train[i][2] != y_train[i][2]:
    bledyVirginica += 1

# print("Liczba bledow ciagu treningowego: ", bledy)

y_result_test = model.predict(x_test)
y_result_test = np.round(y_result_test)

# bledy = 0
bledySetosa = 0
bledyVersicolor = 0
bledyVirginica = 0

print("Ciag treningowy - Bledy Setosa: ", bledySetosa, "Bledy Versicolor: ", bledyVersicolor, "Bledy Virginica: ", bledyVirginica)

for i in range(len(y_test)):
  if y_result_test[i][0] != y_test[i][0]:
    bledySetosa += 1

for i in range(len(y_test)):
  if y_result_test[i][1] != y_test[i][1]:
    bledyVersicolor += 1

for i in range(len(y_test)):
  if y_result_test[i][2] != y_test[i][2]:
    bledyVirginica += 1

print("Ciag testowy - Bledy Setosa: ", bledySetosa, "Bledy Versicolor: ", bledyVersicolor, "Bledy Virginica: ", bledyVirginica)
