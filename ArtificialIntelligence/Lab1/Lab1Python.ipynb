# %%
#Zad1
print("Pierwiastki równania kwadratowego")
def pRW (a,b,c):
    delta = b*b + (-4* a *c)
    if delta < 0:
        return ()
    elif delta == 0:
        return ((-b)/(2*a),)
    else:
        x1=((-b)-delta)/(2*a)
        x2=((-b)+delta)/(2*a)
        return (x1,x2)

print( pRW(4,4,1))
# Out:
# Pierwiastki równania kwadratowego
# (-0.5,)

# %%
#Zad2
import random
r = random.randint(1,10)
i = input("Podaj liczbę:")
i= int(i)
p = 1
while r != i:
    print ("Nie zgadłeś w próbie nr ", p)
    p=p+1
    if r > i:
        print ("Wylosowana liczba jest wieksza")
    else:
        print("Wylosowana liczba jest mniejsza")  
    i = input ("Podaj liczbę:")
    i= int(i)
    
print("Wygraleś w " , p ," próbie")
# Out:
# Podaj liczbę:4
# Nie zgadłeś w próbie nr  1
# Wylosowana liczba jest wieksza
# Podaj liczbę:6
# Nie zgadłeś w próbie nr  2
# Wylosowana liczba jest mniejsza
# Podaj liczbę:5
# Wygraleś w  3  próbie

# %%
#Zad3
ciag1 = "ATCGATTAGC"
#a
print("Dlugosc ciagu to:", len(ciag1))

#b
def walidacjaCiagu(c):
    for i in range(0,len(c),1):
        if (not((c[i] == 'A') or (c[i] == 'T') or (c[i] == 'C') or (c[i] == 'G'))):
            print("nie poprawny ciag")
            break
        elif (i == len(c)):
            print("poprawny ciag")
     
print("")
#poprawny 
print(ciag1)
walidacja_DNA(ciag1)
#niepoprawny
print(ciag2)
ciag2 = "MTCGATTATC"
walidacja_DNA(ciag2)

#c
def ciagKomplementarny(c):
    c2=""
    for i in range(0,len(c),1):
        if(c[i] == 'A'):
            c2= c2+'T'
        elif(c[i] == 'T'):
            c2= c2+'A'
        elif(c[i] == 'C'):
            c2= c2+'G'
        elif(c[i] == 'G'):
            c2= c2+'C'
    return c2

ciag3 = ciagKomplementarny(ciag1)
print("\nCiagi komplementarne:")
print(ciag1)
print(ciag3, "\n")
    

#d
def odwrocCiag(c):
    c2 = ""
    for i in range(len(c)-1, -1 ,-1):
        c2=c2+c[i]
    return c2

print(ciag3)
print("Odwrocony ciag:")
print(odwrocCiag(ciag3),"\n")


#e
def zliczParyZasad(c1,c2):
    zasadaAT=0
    zasadaCG=0
    for i in range(0,len(c1),1):
        if((c1[i]=='A' and c2[i]=='T') or (c1[i]=='T' and c2[i]=='A')):
            zasadaAT=zasadaAT+1
        elif((c1[i]=='C' and c2[i]=='G') or (c1[i]=='G' and c2[i]=='C')):
            zasadaCG=zasadaCG+1
    print("liczba zasad AT: ", zasadaAT, ",liczba zasad CG: ", zasadaCG)
        
zliczParyZasad(ciag1,ciag3)

#f
def liczGG(c):
    licznik = 0
    for i in range(0,len(c)-1, 1):
        if ((c[i] == 'G') and (c[i+1] == 'G')):
            licznik=licznik+1
    print("Liczba sekwencji GG:",licznik)

print()
print(ciag3)
liczGG(ciag3)
ciag5="GGGATGGC"
print(ciag5)
liczGG(ciag5)

#g
def liczATA(c):
    licznik = 0
    for i in range(0,len(c)-1, 1):
        if ((c[i] == 'A') and (c[i+1] == 'T') and (c[i+2] == 'A')):
            licznik=licznik+1
    print("Liczba sekwencji ATA:",licznik)
    
print()
print(ciag3)
liczATA(ciag3)
ciag6="ATATAGC"
print(ciag6)
liczATA(ciag6)
# Out:
# Dlugosc ciagu to: 10
#
# ATCGATTAGC
# poprawny ciag
# MTCGATTATC
# nie poprawny ciag
#
# Ciagi komplementarne:
# ATCGATTAGC
# TAGCTAATCG
#
# TAGCTAATCG
# Odwrocony ciag:
# GCTAATCGAT
#
# liczba zasad AT:  6 ,liczba zasad CG:  4
#
# TAGCTAATCG
# Liczba sekwencji GG: 0
# GGGATGGC
# Liczba sekwencji GG: 3
#
# TAGCTAATCG
# Liczba sekwencji ATA: 0
# ATATAGC
# Liczba sekwencji ATA: 2

# %% [markdown]
# ###
